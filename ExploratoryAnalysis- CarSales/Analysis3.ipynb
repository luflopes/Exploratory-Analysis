# %% [markdown]
# ## Análise Exploratória em Conjunto de Dados do Kaggle
#
# ## Análise 3

# %%
# Imports
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
sns.set(style = "white")
# %matplotlib inline

# %%
# Dataset
clean_data_path = "dataset/autos/autos.csv"
df = pd.read_csv(clean_data_path,encoding = "latin-1")

# %% [markdown]
# ## Preço médio do veículo por tipo de combustível e tipo de caixa de câmbio

# %%
df.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'postalCode', 'lastSeen',
#        'yearOfCreation', 'yearCrawled', 'monthOfCreation', 'monthCrawled',
#        'NoOfDaysOnline', 'NoOfHrsOnline', 'yearsOld', 'monthsOld'],
#       dtype='object')

# %%
pgt1 = df
plt.figure(figsize=(12,6))
ax1 = sns.barplot(data=pgt1, x='fuelType', y='price', hue='gearbox', palette='plasma_r', ci=None)
ax1.set_title('\n Preço médio do veículo por tipo de combustível e tipo de câmbio \n',  fontdict={'fontsize':15})
ax1.set_ylabel('\n Preço Médio \n',  fontdict={'fontsize':13})
ax1.set_xlabel('\n Tipo de Combustível \n',  fontdict={'fontsize':13})
# Out:
# Text(0.5, 0, '\n Tipo de Combustível \n')

# %%
# Salvando o plot
fig.savefig("plots/Analise3/fueltype-vehicleType-price.png")

# %% [markdown]
# ## Potência média de um veículo por tipo de veículo e tipo de caixa de câmbio

# %%
df.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'postalCode', 'lastSeen',
#        'yearOfCreation', 'yearCrawled', 'monthOfCreation', 'monthCrawled',
#        'NoOfDaysOnline', 'NoOfHrsOnline', 'yearsOld', 'monthsOld'],
#       dtype='object')

# %%
pgt2 = df
plt.figure(figsize=(12,6))
ax2 = sns.barplot(data=pgt2, x='vehicleType', y='powerPS', hue='gearbox', ci=None, palette='plasma_r')
ax2.set_ylabel('\n Potência Média \n', fontdict={'fontsize':13})
ax2.set_xlabel('\n Tipo de Veículo \n', fontdict={'fontsize':13})
ax2.set_title('\n Potência média de um veículo por tipo de veículo e tipo de câmbio \n', fontdict={'fontsize':15})
# Out:
# Text(0.5, 1.0, '\n Potência média de um veículo por tipo de veículo e tipo de câmbio \n')

# %%
# Salvando o plot
fig.savefig("plots/Analise3/vehicletype-fueltype-power.png")
